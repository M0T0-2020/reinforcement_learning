# %%
import os, sys 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from collections import deque

import torch
from torch.distributions import Categorical

import gym

import warnings
warnings.filterwarnings('ignore')

# %%
sys.path.append('/Users/kanoumotoharu/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/A2C_2/')
from agent import  Agent
sys.path.append('/Users/kanoumotoharu/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/Memory/')
from PrioritizedExperienceMemoryNsplit_add_value import ProportionalReplayNsplitMemory, RankReplayNsplitMemory

# %%
class Environment:
    def get_state(self, env, _obs):
        env_low = env.observation_space.low 
        env_high = env.observation_space.high 
        # normalize
        state = (_obs - env_low)/(env_high - env_low)
        return state.tolist()

    def get_reward(self, env, obs, next_obs, reward, action):
        low = env.observation_space.low[0]
        high = env.observation_space.high[0]
        reward = float((next_obs[0]-low)/(high-low))
        return reward
    
    def get_value(self, env, obs, next_obs, reward, action):
        low = env.observation_space.low[0]
        high = env.observation_space.high[0]
        
        value = float((next_obs[0]-low)/(high-low))
        value/=2
        if value<0.7:
            value = 0
        if value>0.9:
            value *= 2
        return value
    
    def get_action(self,env, action):
        action = int(action)
        return action

    def get_data(self, env, obs, next_obs, reward, action):
        state = self.get_state(env, obs)
        action = self.get_action(env, action)
        next_state = self.get_state(env, next_obs)
        reward = self.get_reward(env, obs, next_obs, reward, action)
        value = self.get_value(env, obs, next_obs, reward, action)

        return state, action, next_state, reward, value

# %%
from collections import deque

    
class Environment2:
    #stateの入力を増やしてみる
    def __init__(self, n=5):
        self.states_list = deque(maxlen=n)
        self.n = n
        
    def get_state(self, env, _obs):
        env_low = env.observation_space.low 
        env_high = env.observation_space.high 
        # normalize
        state = ((_obs - env_low)/(env_high - env_low)).tolist()
        if len(self.states_list)==0:
            for i in range(n):
                self.states_list.appendleft(state)
        return np.array(self.states_list).flatten().tolist()
    
    def get_nextstate(self, env, _obs):
        env_low = env.observation_space.low 
        env_high = env.observation_space.high 
        # normalize
        state = ((_obs - env_low)/(env_high - env_low)).tolist()
        self.states_list.appendleft(state)
        return np.array(self.states_list).flatten().tolist()

    def get_reward(self, env, obs, next_obs, reward, action):
        low = env.observation_space.low[0]
        high = env.observation_space.high[0]
        reward = float((next_obs[0]-low)/(high-low))
        return reward
    
    def get_value(self, env, obs, next_obs, reward, action):
        low = env.observation_space.low[0]
        high = env.observation_space.high[0]
        
        value = float((next_obs[0]-low)/(high-low))
        value/=2
        if value<0.7:
            value = 0
        if value>0.9:
            value *= 2
        return value
    
    def get_action(self,env, action):
        action = int(action)
        return action

    def get_data(self, env, obs, next_obs, reward, action):
        state = self.get_state(env, obs)
        action = self.get_action(env, action)
        next_state = self.get_state(env, next_obs)
        reward = self.get_reward(env, obs, next_obs, reward, action)
        value = self.get_value(env, obs, next_obs, reward, action)

        return state, action, next_state, reward, value

# %%
#make env
env = gym.make('MountainCar-v0')

# %%
action_space = env.action_space.n

#replay_memory = Replay_Memory(100000)
replay_memory = ProportionalReplayNsplitMemory(500,n=60)
#replay_memory = RankReplayNsplitMemory(2000,n=60, alpha=0)
n = 10
environment = Environment2(n)
agent = Agent(action_space=action_space, nSplit=True, sam=True, input_size=2*n, hidden_layers=[32,64])

# %%
# 楽観的初期化
loss_list = agent.init_param_optim(70, env, environment)
plt.plot(loss_list)

# %%
actions = []
rewards = []
values = []
loss = []

# %%
# 10000エピソードで学習する
for episode in tqdm(range(10)):
    
    total_reward = 0
    total_value = 0
    observation = env.reset()
    environment = Environment2(n)
    replay_memory.ResetTemporalMemory()
    
    for _ in range(10000):
        env.render()
        
        # ε-グリーディ法で行動を選択        
        now_state = environment.get_state(env, observation)
        now_state = torch.FloatTensor([now_state])
        action =  agent.get_action(now_state)
        actions.append(action)
        
        #環境を取得
        next_observation, reward, done, _ = env.step(action)
        
        # observe environment data
        state, action, next_state, reward, value = environment.get_data(env, observation, next_observation, reward, action)
        replay_memory.push(state, action, next_state, reward, value)

        #optim parameters
        _loss = agent.update_agent(replay_memory)
        total_reward += reward
        total_value += value
        
        if _loss is not None:
            loss.append(_loss)
        observation = next_observation
        
        if observation[0]>=env.observation_space.high[0]-0.001:
            # doneがTrueになったら１エピソード終了
            if episode%100 == 0:
                if episode==0:
                    mean_total_reward = total_reward
                else:
                    m = episode//100
                    mean_total_reward = np.mean(rewards[(m-1)*100:m*100])
                print(f'episode: {episode}, total_reward　mean: {mean_total_reward}')
            break
    rewards.append(total_reward)
    values.append(total_value)
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-dcd9a192faa5> in <module>
#      25
#      26         #optim parameters
# ---> 27         _loss = agent.update_agent(replay_memory)
#      28         total_reward += reward
#      29         total_value += value
#
# ~/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/A2C_2/agent.py in update_agent(self, replay_memory)
#      77             batch_size = min(len(replay_memory), self.batch)
#      78             batch = self.batcher.make_batch(replay_memory, batch_size)
# ---> 79             loss, priorityloss = self.optimize_nn(batch, self.model, self.optimizer, self.gamma, self.device, self.steps)
#      80             if (loss is not None) and ('weight' in batch.keys()):
#      81                 replay_memory.updatePriority(batch['index'], priorityloss)
#
# ~/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/A2C_2/optimize_util.py in optimize_nn_nSplit_sam(batch, model, optimizer, gamma, device, step)
#     186             loss.backward()
#     187             torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
# --> 188             optimizer.first_step(zero_grad=True)
#     189         if i==1:
#     190             # second forward-backward pass
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/optimizer/sam.py in first_step(self, zero_grad)
#      30     @torch.no_grad()
#      31     def first_step(self, zero_grad=False):
# ---> 32         grad_norm = self._grad_norm()
#      33         for group in self.param_groups:
#      34             scale = group["rho"] / (grad_norm + 1e-12)
#
# ~/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/optimizer/sam.py in _grad_norm(self)
#      67                     torch.stack([
#      68                         p.grad.norm(p=2).to(shared_device)
# ---> 69                         for group in self.param_groups for p in group["params"]
#      70                         if p.grad is not None
#      71                     ]),
#
# ~/Desktop/machine_learning/強化学習/reinforcement_learning/RL_algorithms/optimizer/sam.py in <listcomp>(.0)
#      68                         p.grad.norm(p=2).to(shared_device)
#      69                         for group in self.param_groups for p in group["params"]
# ---> 70                         if p.grad is not None
#      71                     ]),
#      72                     p=2
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/tensor.py in grad(self)
#     945             return handle_torch_function(Tensor.grad.__get__, relevant_args, self)  # type: ignore[attr-defined]
#     946
# --> 947         if self.requires_grad and not hasattr(self, "retains_grad") and not self.is_leaf and self._grad is None:
#     948             warnings.warn("The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad "
#     949                           "attribute won't be populated during autograd.backward(). If you indeed want the gradient "
#
# KeyboardInterrupt:

# %%
env.close()

# %%
#agent.policy_net.state_dict()

# %%
loss_df = pd.DataFrame(loss, columns=['loss'])
reward_df = pd.DataFrame(rewards, columns=['reward'])
action_df = pd.DataFrame(actions, columns=['action'])

loss_df['loss_r30'] = loss_df['loss'].rolling(30,min_periods=1).mean()
reward_df['reward_r30'] = reward_df['reward'].rolling(30,min_periods=1).mean()
action_df['action'] = action_df['action'].map({0:"push left", 1:"no push", 2:"push right"})

# %%
plt.figure(figsize=(30,5))
plt.plot(loss_df['loss_r30'])
plt.title('Loss')
plt.show()

plt.figure(figsize=(30,5))
plt.plot(reward_df['reward_r30'])
plt.title('Reward')
plt.show()

plt.figure(figsize=(10,5))
sns.countplot(action_df["action"], order=["push left", "no push","push right"])
plt.title("action  count")
plt.show()

# %%
total_reward = 0
observation = env.reset()
for _ in range(10000):
        env.render()
        # ε-グリーディ法で行動を選択        
        now_state = environment.get_state(env, observation)
        now_state = torch.FloatTensor([now_state])
        action =  agent.get_action(now_state)
        actions.append(action)
        
        next_observation, reward, done, _ = env.step(action)
        total_reward += reward
        observation = next_observation
        if observation[0]>=env.observation_space.high[0]-0.001:
            rewards.append(total_reward)
            # doneがTrueになったら１エピソード終了
            if episode%100 == 0:
                if episode==0:
                    mean_total_reward = total_reward
                else:
                    m = episode//100
                    mean_total_reward = np.mean(rewards[(m-1)*100:m*100])
                print(f'episode: {episode}, total_reward　mean: {mean_total_reward}')
            break
            
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-826198a1e368> in <module>
#       2 observation = env.reset()
#       3 for _ in range(10000):
# ----> 4         env.render()
#       5         # ε-グリーディ法で行動を選択
#       6         now_state = environment.get_state(env, observation)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gym/envs/classic_control/mountain_car.py in render(self, mode)
#     173         self.cartrans.set_rotation(math.cos(3 * pos))
#     174
# --> 175         return self.viewer.render(return_rgb_array=mode == 'rgb_array')
#     176
#     177     def get_keys_to_action(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#     108         self.transform.enable()
#     109         for geom in self.geoms:
# --> 110             geom.render()
#     111         for geom in self.onetime_geoms:
#     112             geom.render()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render(self)
#     178         for attr in reversed(self.attrs):
#     179             attr.enable()
# --> 180         self.render1()
#     181         for attr in self.attrs:
#     182             attr.disable()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render1(self)
#     300         glBegin(GL_LINE_LOOP if self.close else GL_LINE_STRIP)
#     301         for p in self.v:
# --> 302             glVertex3f(p[0], p[1],0)  # draw each vertex
#     303         glEnd()
#     304     def set_linewidth(self, x):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      85
#      86
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:

# %%
x = agent.model(now_state)['policy']
print(x)
a = Categorical(logits=x)
print(a)
print(a.entropy())
# Out:
# tensor([[0.3293, 0.3255, 0.3225]], grad_fn=<AddmmBackward>)
# Categorical(logits: torch.Size([1, 3]))
# tensor([1.0986], grad_fn=<NegBackward>)

# %%
x
# Out:
# tensor([[0.3293, 0.3255, 0.3225]], grad_fn=<AddmmBackward>)

# %%
0.999**5000
# Out:
# 0.006721111959865588

# %%
torch.nn.LogSoftmax()(x)#(torch.nn.Softmax()(x))
# Out:
# tensor([[-1.0951, -1.0989, -1.1019]], grad_fn=<LogSoftmaxBackward>)

# %%
a.probs, a.logits
# Out:
# (tensor([[0.3345, 0.3333, 0.3322]], grad_fn=<SoftmaxBackward>),
#  tensor([[-1.0951, -1.0989, -1.1019]], grad_fn=<SubBackward0>))

# %%
a.sample()
# Out:
# tensor([2])

# %%
now_state
# Out:
# tensor([[0.3511, 0.5000, 0.3511, 0.5000, 0.3511, 0.5000, 0.3511, 0.5000, 0.3511,
#          0.5000, 0.3511, 0.5000, 0.3511, 0.5000, 0.3511, 0.5000, 0.3511, 0.5000,
#          0.3511, 0.5000]])

# %%
low_0 = env.observation_space.low[0]
high_0 = env.observation_space.high[0]
low_1 = env.observation_space.low[1]
high_1 = env.observation_space.high[1]

df = []
for x_0 in np.arange(low_0, high_0,0.05):
    x=[]
    tmp_df = pd.DataFrame(index=np.arange(low_1, high_1,0.01))
    for x_1 in np.arange(low_1, high_1,0.01):
        y = []
        for _ in range(n):
            y+=[x_0, x_1]
        x.append(y)

    x = torch.FloatTensor(x)
    y = agent.model(x)['value'].detach().numpy().flatten()
    tmp_df[x_0] = y
    df.append(tmp_df)

df = pd.concat(df, axis=1)
plt.figure(figsize=(30,10))
sns.heatmap(df, cmap='coolwarm')
plt.title('value')
plt.show()

# %%
low_0 = env.observation_space.low[0]
high_0 = env.observation_space.high[0]
low_1 = env.observation_space.low[1]
high_1 = env.observation_space.high[1]

df = []
for x_0 in np.arange(low_0, high_0,0.05):
    x=[]
    tmp_df = pd.DataFrame(index=np.arange(low_1, high_1,0.01))
    for x_1 in np.arange(low_1, high_1,0.01):
        y = []
        for _ in range(n):
            y+=[x_0, x_1]
        x.append(y)

    x = torch.FloatTensor(x)
    y = agent.model(x)['return'].detach().numpy().flatten()
    tmp_df[x_0] = y
    df.append(tmp_df)

df = pd.concat(df, axis=1)
plt.figure(figsize=(30,10))
sns.heatmap(df, cmap='coolwarm')
plt.title('return')
plt.show()

# %%
low_0 = env.observation_space.low[0]
high_0 = env.observation_space.high[0]
low_1 = env.observation_space.low[1]
high_1 = env.observation_space.high[1]

df = []
for x_0 in np.arange(low_0, high_0,0.05):
    x=[]
    tmp_df = pd.DataFrame(index=np.arange(low_1, high_1,0.01))
    for x_1 in np.arange(low_1, high_1,0.01):
        y = []
        for _ in range(n):
            y+=[x_0, x_1]
        x.append(y)

    x = torch.FloatTensor(x)
    y = agent.model(x)['policy'].detach().numpy()
    tmp_df[x_0] = y.argmax(1)
    df.append(tmp_df)

df = pd.concat(df, axis=1)
plt.figure(figsize=(30,10))
sns.heatmap(df, cmap='coolwarm')
plt.title('policy')
plt.show()

# %%
low_0 = env.observation_space.low[0]
high_0 = env.observation_space.high[0]
low_1 = env.observation_space.low[1]
high_1 = env.observation_space.high[1]

df = []
for x_0 in np.arange(low_0, high_0,0.05):
    x=[]
    tmp_df = pd.DataFrame(index=np.arange(low_1, high_1,0.01))
    for x_1 in np.arange(low_1, high_1,0.01):
        y = []
        for _ in range(n):
            y+=[x_0, x_1]
        x.append(y)

    x = torch.FloatTensor(x)
    y = agent.model(x)['policy'].detach()
    y = Categorical(logits=y).entropy()
    tmp_df[x_0] = y
    df.append(tmp_df)

df = pd.concat(df, axis=1)
plt.figure(figsize=(30,10))
sns.heatmap(df, cmap='coolwarm')
plt.title('entropy')
plt.show()

# %%
print(Categorical(
    logits = torch.FloatTensor([0,0,0])
).entropy())

print(Categorical(
    logits = torch.FloatTensor([1,1,1])
).entropy())

print(Categorical(
    logits = torch.FloatTensor([1,0,1])
).entropy())

print(Categorical(
    logits = torch.FloatTensor([0,100,0])
).entropy())

print(Categorical(
    logits =agent.model(x)['policy'].detach()
).entropy())
# Out:
# tensor(1.0986)
# tensor(1.0986)
# tensor(1.0174)
# tensor(7.5670e-42)
# tensor([1.0986, 1.0986, 1.0986, 1.0986, 1.0986, 1.0986, 1.0986, 1.0986, 1.0986,
#         1.0986, 1.0986, 1.0986, 1.0986, 1.0986, 1.0986])

# %%
a = Categorical(
    logits = torch.FloatTensor([1,20,50])
)
print(a.entropy())
# Out:
# tensor(2.8073e-12)
